# %% [markdown]
# ## This steps and code provided by a tutorial on downloading data from Open Image, can be found in [youtube](https://www.youtube.com/watch?v=U2V2tUwquAA&t)

# %%
# !git clone https://github.com/EscVM/OIDv4_ToolKit.git
# Out:
# Cloning into 'OIDv4_ToolKit'...
# remote: Enumerating objects: 422, done.
# remote: Total 422 (delta 0), reused 0 (delta 0), pack-reused 422
# Receiving objects: 100% (422/422), 34.08 MiB | 35.79 MiB/s, done.
# Resolving deltas: 100% (146/146), done.

# %%
# !pip3 install -r /content/OIDv4_ToolKit/requirements.txt
# Out:
# ...
#      |████████████████████████████████| 3.6MB 2.9MB/s
# ...
#      |████████████████████████████████| 81kB 9.2MB/s
# ...
#      |████████████████████████████████| 7.6MB 35.3MB/s
# ...
#      |████████████████████████████████| 552kB 31.4MB/s
# ...
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# ERROR: botocore 1.20.84 has requirement urllib3<1.27,>=1.25.4, but you'll have urllib3 1.24.3 which is incompatible.
# ...
#   Found existing installation: docutils 0.17.1
#     Uninstalling docutils-0.17.1:
#       Successfully uninstalled docutils-0.17.1
# ...

# %%
# !python /content/OIDv4_ToolKit/main.py downloader --classes Apple Carrot Orange --type_csv train --limit 300
# Out:
# 		   ___   _____  ______            _    _
# 		 .'   `.|_   _||_   _ `.         | |  | |
# 		/  .-.  \ | |    | | `. \ _   __ | |__| |_
# 		| |   | | | |    | |  | |[ \ [  ]|____   _|
# 		\  `-'  /_| |_  _| |_.' / \ \/ /     _| |_
# 		 `.___.'|_____||______.'   \__/     |_____|
#
#
#              _____                    _                 _
#             (____ \                  | |               | |
#              _   \ \ ___  _ _ _ ____ | | ___   ____  _ | | ____  ____
#             | |   | / _ \| | | |  _ \| |/ _ \ / _  |/ || |/ _  )/ ___)
#             | |__/ / |_| | | | | | | | | |_| ( ( | ( (_| ( (/ /| |
#             |_____/ \___/ \____|_| |_|_|\___/ \_||_|\____|\____)_|
#
#
#     [INFO] | Downloading Apple.
#    [ERROR] | Missing the class-descriptions-boxable.csv file.
# [DOWNLOAD] | Do you want to download the missing file? [Y/n] y
# ...145%, 0 MB, 43322 KB/s, 0 seconds passed
# ...

# %%
# !python /content/OIDv4_ToolKit/main.py downloader --classes Apple Carrot Orange --type_csv test --limit 100
# Out:
# 		   ___   _____  ______            _    _
# 		 .'   `.|_   _||_   _ `.         | |  | |
# 		/  .-.  \ | |    | | `. \ _   __ | |__| |_
# 		| |   | | | |    | |  | |[ \ [  ]|____   _|
# 		\  `-'  /_| |_  _| |_.' / \ \/ /     _| |_
# 		 `.___.'|_____||______.'   \__/     |_____|
#
#
#              _____                    _                 _
#             (____ \                  | |               | |
#              _   \ \ ___  _ _ _ ____ | | ___   ____  _ | | ____  ____
#             | |   | / _ \| | | |  _ \| |/ _ \ / _  |/ || |/ _  )/ ___)
#             | |__/ / |_| | | | | | | | | |_| ( ( | ( (_| ( (/ /| |
#             |_____/ \___/ \____|_| |_|_|\___/ \_||_|\____|\____)_|
#
#
#     [INFO] | Downloading Apple.
#    [ERROR] | Missing the class-descriptions-boxable.csv file.
# [DOWNLOAD] | Do you want to download the missing file? [Y/n] Y
# ...145%, 0 MB, 41733 KB/s, 0 seconds passed
# ...

# %%
# !zip -r /content/OID.zip /content/OID
# Out:
#   adding: content/OID/ (stored 0%)
#   adding: content/OID/csv_folder/ (stored 0%)
#   adding: content/OID/csv_folder/test-annotations-bbox.csv (deflated 75%)
#   adding: content/OID/csv_folder/class-descriptions-boxable.csv (deflated 51%)
#   adding: content/OID/Dataset/ (stored 0%)
#   adding: content/OID/Dataset/test/ (stored 0%)
#   adding: content/OID/Dataset/test/Orange/ (stored 0%)
#   adding: content/OID/Dataset/test/Orange/8761a1e0a08655ae.jpg (deflated 0%)
#   adding: content/OID/Dataset/test/Orange/f8a3970b24df8aab.jpg (deflated 0%)
#   adding: content/OID/Dataset/test/Orange/c13f5a7d0c7e55e6.jpg (deflated 0%)
#   adding: content/OID/Dataset/test/Orange/43e1ac17fcbd97bf.jpg (deflated 1%)
#   adding: content/OID/Dataset/test/Orange/30e5bf76da7b0e30.jpg (deflated 0%)
#   adding: content/OID/Dataset/test/Orange/3abf8c716190e5ff.jpg (deflated 0%)
#   adding: content/OID/Dataset/test/Orange/e09dca7b5bfa5d3c.jpg (deflated 0%)
# ...

# %%
from google.colab import files
files.download("/content/OID.zip")
